jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/446.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/428.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/423.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/394.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/406.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/388.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/443.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/397.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/391.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/431.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/430.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/384.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/393.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/427.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/436.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/408.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/372.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/447.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/396.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/409.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/418.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/399.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/444.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/401.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/410.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/378.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/404.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/437.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/414.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/374.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/421.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/375.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/367.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/379.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/392.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/425.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/445.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/422.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/373.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/370.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/420.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/371.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/380.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/387.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/448.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/473.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/450.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/463.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/470.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/459.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/482.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/460.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/449.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/481.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/469.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/477.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/471.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/452.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/451.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/472.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/461.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/453.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/454.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/467.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/475.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/462.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/476.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/456.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/455.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/466.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/464.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/479.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Negative/478.jpg
# Glaucoma_Positive
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/116.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/036.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/138.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/182.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/165.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/229.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/087.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/072.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/233.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/180.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/213.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/160.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/245.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/097.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/158.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/076.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/171.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/086.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/093.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/181.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/037.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/240.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/094.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/225.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/159.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/069.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/050.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/041.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/110.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/208.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/168.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/241.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/228.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/442.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/354.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/269.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/306.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/283.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/353.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/362.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/286.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/457.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/300.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/424.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/327.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/337.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/285.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/270.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/382.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/336.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/284.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/246.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/381.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/312.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/385.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/294.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/330.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/289.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/345.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/317.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/441.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/440.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/390.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/383.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/432.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/426.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/465.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/301.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/395.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/340.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/348.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/349.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/273.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/359.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/458.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/429.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/419.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/402.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/305.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/366.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/277.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/304.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/398.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/278.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/386.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/407.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/439.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/433.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/247.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/389.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/377.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/293.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/322.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/578.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/588.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/595.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/480.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/549.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/532.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/512.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/519.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/528.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/474.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/592.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/524.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/533.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/572.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/571.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/550.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/505.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/593.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/545.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/516.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/468.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/514.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/511.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/580.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/589.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/523.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/507.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/490.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/586.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/508.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/557.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/496.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/560.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/556.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/506.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/515.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/558.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/582.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/584.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/591.jpg
# /content/drive/MyDrive/preprocessedData/Train/Glaucoma_Positive/486.jpg

# %%
test_images = []
test_labels = [] 
for directory_path in glob.glob("/content/drive/MyDrive/preprocessedData/Validation/*"):
    fruit_label = directory_path.split("/")[-1]
    for img_path in glob.glob(os.path.join(directory_path, "*.jpg")):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)
        img = cv2.resize(img, (SIZE, SIZE))
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        test_images.append(img)
        test_labels.append(fruit_label)

#Convert lists to arrays                
test_images = np.array(test_images)
test_labels = np.array(test_labels)

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(test_labels)
test_labels_encoded = le.transform(test_labels)
le.fit(train_labels)
train_labels_encoded = le.transform(train_labels)

# %%
x_train, y_train, x_test, y_test = train_images, train_labels_encoded, test_images, test_labels_encoded

# %%
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
from keras.utils import to_categorical
y_train_one_hot = to_categorical(y_train)
y_test_one_hot = to_categorical(y_test)

# %%
VGG_model = VGG16(weights='imagenet', include_top=False, input_shape=(SIZE, SIZE, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step

# %%
for layer in VGG_model.layers:
	layer.trainable = False

# %%
VGG_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 256, 256, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 256, 256, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 128, 128, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 128, 128, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 128, 128, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 64, 64, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 64, 64, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 32, 32, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 32, 32, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 16, 16, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
feature_extractor=VGG_model.predict(x_train)

# %%
features = feature_extractor.reshape(feature_extractor.shape[0], -1)

# %%
X_for_RF = features

# %%
from sklearn.ensemble import RandomForestClassifier
RF_model = RandomForestClassifier(n_estimators = 50, random_state = 42)

# %%
RF_model.fit(X_for_RF, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=50,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
X_test_feature = VGG_model.predict(x_test)
X_test_features = X_test_feature.reshape(X_test_feature.shape[0], -1)

# %%
prediction_RF = RF_model.predict(X_test_features)

# %%
prediction_RF = le.inverse_transform(prediction_RF)

# %%
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, prediction_RF))
# Out:
# Accuracy =  0.7

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(test_labels, prediction_RF)

# %%
sns.heatmap(cm, annot=True)

# %%
n=np.random.randint(0, x_test.shape[0])
img = x_test[n]
plt.imshow(img)
input_img = np.expand_dims(img, axis=0) #Expand dims so the input is (num images, x, y, c)
input_img_feature=VGG_model.predict(input_img)
input_img_features=input_img_feature.reshape(input_img_feature.shape[0], -1)
prediction_RF = RF_model.predict(input_img_features)[0] 
prediction_RF = le.inverse_transform([prediction_RF])  #Reverse the label encoder to original name
print("The prediction for this image is: ", prediction_RF)
print("The actual label for this image is: ", test_labels[n])
# Out:
# The prediction for this image is:  ['Glaucoma_Positive']
# The actual label for this image is:  Glaucoma_Negative
